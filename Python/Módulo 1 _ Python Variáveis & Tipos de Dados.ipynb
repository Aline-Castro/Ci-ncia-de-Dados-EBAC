# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Variáveis & Tipos de Dados
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Introdução ao Google Colab;</li>
#   <li>Variáveis;</li>
#   <li>Números;</li>
#   <li><i>Strings;</i></li>
#   <li>Boleanos.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Google Colab

# %% [markdown]
# Crie uma célula de código que escreva o texto "Olá mundo!", utilize o comando `print`.

# %% [markdown]
# Crie uma célua de texto e adicione uma imagem.

# %%
print('Olá, mundo!')
# Out:
# Olá, mundo!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Números

# %% [markdown]
# Preencha as células de código para preencher os valores de (A), (B) e (C) na tabela de ticket médio abaixo:
#
# <br>
#
# | Dia   | Valor Total Vendas | Qtd Total Vendas | Ticket Medio |
# |-------|--------------------|------------------|--------------|
# | 19/01 | (A)                | 3                | 320.52       |
# | 20/01 | 834.47             | (B)              | 119.21       |
# | 23/01 | 15378.12           | 5                | (C)          |

# %%
# definindo os valores das variáveis de acordo com a tabela fornecida:
Valor_Total_Vendas_B = 834.47
Valor_Total_Vendas_C = 15378.12

Qtd_Total_Vendas_A = 3
Qtd_Total_Vendas_C = 5

Ticket_Medio_A = 320.52
Ticket_Medio_B = 119.21

# %%
# (A)
Valor_Total_Vendas = Ticket_Medio_A * Qtd_Total_Vendas_A

print(f'Valor total de vendas do dia 19/01: {Valor_Total_Vendas}')
# Out:
# Valor total de vendas do dia 19/01: 961.56

# %%
# (B)
Qtd_Total_Vendas = int(Valor_Total_Vendas_B / Ticket_Medio_B)

print(f'Quantidade total de vendas do dia 20/01: {Qtd_Total_Vendas}')
# Out:
# Quantidade total de vendas do dia 20/01: 7

# %%
# (C)
Ticket_Medio = Valor_Total_Vendas_C / Qtd_Total_Vendas_C

print(f'Ticket Médio do dia 21/01: {Ticket_Medio}')
# Out:
# Ticket Médio do dia 21/01: 3075.6240000000003

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Strings

# %% [markdown]
# Aplique três métodos distintos na *string* abaixo, você pode conferir alguns métodos neste [link](https://www.w3schools.com/python/python_ref_string.asp):

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'

# %%
print(cancao.upper())
print(cancao.lower())
print(cancao.replace('roda pião', 'solta pipa'))
# Out:
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.
# roda mundo, roda gigante, roda moinho, roda pião.
# Roda mundo, roda gigante, roda moinho, solta pipa.

# %% [markdown]
# Extraia da string abaixo o valor da taxa **selic** na variável `selic` e o valor do **ano** na variavel `ano`. Imprima os valores na tela.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'
selic = noticia.split()[3]
print(selic)

ano = noticia.split()[12]
print(ano)
# Out:
# 2,75%
# 6

# %% [markdown]
# ---

# %% [markdown]
# ## 4\. Booleanos

# %% [markdown]
# Utilize a tabela da verdade para responder: qual o valor da variável x?

# %%
a = False
b = True

x = not a & b

# %% [markdown]
# not a = True
# b = True
# x = True AND True
# x = True
